# %%
import matplotlib.pyplot as plt
import cv2
import glob

# %%
path = glob.glob(r'C:\Users\YoutechBD\Linear Algebra Assignment\images\*.jpg')

# %%
for file in path:
    print(file)
# Out:
# C:\Users\YoutechBD\Linear Algebra Assignment\images\math1p1.jpg
# C:\Users\YoutechBD\Linear Algebra Assignment\images\math1p2.jpg
# C:\Users\YoutechBD\Linear Algebra Assignment\images\math1p3.jpg

# %%
img=cv2.imread(file)

# %%
plt.imshow(img)
